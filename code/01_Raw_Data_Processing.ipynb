# %% [markdown]
# # Data Processing and Cleaning
#
# ---
# ### Objective:
#
# In this notebook, we will extract relevant miRNA expression data from the raw data file dump obtained from the National Cancer Institute (NCI) Genomics Data Commons data portal and create a working dataset to prepare it for visualization and modeling.

# %% [markdown]
# ## Import Libraries

# %%
from IPython.display import clear_output
import os
import sys
import pandas as pd
import numpy as np
import time
import pickle

# %% [markdown]
# ## Raw Data Processing

# %%
# Go to directory that contains the downloaded files
directory = '/Users/surajsakaram/GA_DSI/capstone/'
os.chdir(directory)

# %%
# Check to see that all your files have been downloaded
# There should be a total of 4,068 

len([i for i in os.listdir('./raw_data') if i != '.DS_Store'])
# Out:
# 4068

# %%
os.listdir('./raw_data')[:5]
# Out:
# ['dc8d96ef-81eb-41c8-a486-02d107c1a137',
#  '93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b',
#  '6d869125-0f2b-406a-a1aa-4b352b2247d3',
#  '41dbd6ab-871d-4ee4-be13-392b4995f6ce',
#  '322badf4-b70d-4f90-ac44-d2f30e52f03c']

# %% [markdown]
# - These are directories named as the file [UUIDs](https://docs.gdc.cancer.gov/Data/Data_Model/GDC_Data_Model/) for the txt files that were downloaded.

# %% [markdown]
# #### Let's take a look at one of the data files we've downloaded.

# %%
# Set data file path and open it up as a dataframe 
path = './raw_data/46dc2547-0ffe-4bfa-ab8a-bfe04c9d1fc9/2c9af122-8b71-4e50-81b2-e95a5eeaeb03.mirbase21.mirnas.quantification.txt'

# Txt files are tab-delimited 
txt_file = pd.read_csv(path, delimiter='\t')
txt_file.head()
# Out:
#        miRNA_ID  read_count  reads_per_million_miRNA_mapped cross-mapped
# 0  hsa-let-7a-1       56851                    12062.449502            N
# 1  hsa-let-7a-2       56132                    11909.894557            Y
# 2  hsa-let-7a-3       56890                    12070.724388            N
# 3    hsa-let-7b       58020                    12310.483898            N
# 4    hsa-let-7c       22880                     4854.599648            Y

# %% [markdown]
# #### Goal: Extract out the `reads_per_million_miRNA_mapped` column from each file and store it as a dataframe.

# %%
# Create function that will return a list of file paths for the txt files we want to process

def fetch_file_paths(directory, ext='.mirnas.quantification.txt'):
    
    '''
    ** Description **
    Extract out files of your choosing from subdirectories by specifying file ending or extension.
    
    ** Parameters **
    directory: filepath to parent directory 
    ext: file extension or ending to search by
    '''
    
    file_paths = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if(file.endswith(ext)):
                file_paths.append(os.path.join(root, file))
    
    return file_paths

# %%
# Get list of file paths for txt files
file_path_list = fetch_file_paths('./raw_data')
file_path_list[0:2]
# Out:
# ['./raw_data/dc8d96ef-81eb-41c8-a486-02d107c1a137/960e161b-c2da-496e-9aaf-f73a6e14ee46.mirbase21.mirnas.quantification.txt',
#  './raw_data/93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b/87d84d73-132c-44dc-9aa0-155665590242.mirbase21.mirnas.quantification.txt']

# %% [markdown]
# - This list of file paths will make it easy to access each text file and extract out the relevant columns.

# %%
# Create a function that will return a dataframe with the relevant column extracted out from each file

def process_files(list_of_file_paths):
    # create a dataframe with the miRNA IDs using one of the files
    df = pd.read_csv(list_of_file_paths[0], delimiter='\t')
    df.drop([col for col in df.columns if col != 'miRNA_ID'], axis=1, inplace=True)
    
    n_files = len(list_of_file_paths)
    
    for i, file in enumerate(list_of_file_paths):
        ## Track progress ##
        clear_output(wait=True)
        print(f'Processing file {i}/{n_files}')
        
        # file manipulation
        sample_id = file.split('/')[1]
        tmp_df = pd.read_csv(file, delimiter='\t')
        tmp_df.rename(columns={'reads_per_million_miRNA_mapped': sample_id}, inplace=True)
        df = pd.merge(df, tmp_df[['miRNA_ID', sample_id]], how='outer', on='miRNA_ID')
    
    return df

# %% [markdown]
# **Note**: The below cell blocks are intentionally commented out so as not to be run each time the notebook is opened. The process of accessing each file and extracting out information takes a considerable amount of time. After the data has been processed, the resulting dataframe is pickled ([serialized](https://www.datacamp.com/community/tutorials/pickle-python-tutorial)). This allows us to easily load up the pickled dataframe object if the need should arise downstream.

# %%
# %time
# df = process_files(file_path_list)

# %%
# # Serialize the dataframe object 
# pickle.dump(df, open('./data/processed_data.pk', 'wb'))

# %% [markdown]
# ## Format the Dataframe

# %% [markdown]
# Let $(x_{i}, y_{i})^{n}_{i = 1}$ be a collection of n observations, where $x_{i}$ is a vector consisting of the expression levels of $m$ genes for the $i$-th observation, and $y_{i}$ is the class label or tumor type of the $i$-th observation, $i = 1, ..., n$.
#
# Put simply, the rows should be the samples with the columns as the miRNA. The values of the matrix represent the expression level of a given miRNA in a given sample. Each sample would have its associated tumor diagnosis.
#
# Later, in the modeling phase, the tumor type will be the target value to predict based on the gene expression data.

# %%
# Load in the pickled dataframe object 
miRNA_df = pickle.load(open('./data/processed_data.pk', 'rb'));

# %%
# View the dataframe
miRNA_df.head()
# Out:
#        miRNA_ID  dc8d96ef-81eb-41c8-a486-02d107c1a137  \
# 0  hsa-let-7a-1                           3530.574305
# 1  hsa-let-7a-2                           3545.647914
# 2  hsa-let-7a-3                           3516.338118
# 3    hsa-let-7b                          13112.365384
# 4    hsa-let-7c                           1015.793793
#
#    93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b  6d869125-0f2b-406a-a1aa-4b352b2247d3  \
# 0                           5860.628124                          12710.168915
# 1                           5770.822052                          12822.741990
# 2                           5873.585219                          12923.054631
# 3                          32816.747358                           8665.340311
# 4                           2379.637523                            504.349668
#
#    41dbd6ab-871d-4ee4-be13-392b4995f6ce  322badf4-b70d-4f90-ac44-d2f30e52f03c  \
# 0                           8612.209891                          10317.399990
# 1                           8453.920962                          10054.249488
# 2                           8830.260967                          10189.749276
# 3                          33663.855692                          24500.675020
# 4                           1540.894268                           3229.273903
#
#    d681c69f-3020-463b-90c0-bd9435e3f216  28665a83-f3fe-4ebc-a421-2ab1b40ec796  \
# 0                          39795.949557                          16039.138165
# 1                          39660.130365                          15971.824671
# 2                          39721.766849                          15966.266676
# 3                          94361.331089                           7233.421582
# 4                           3103.801144                           2654.868896
#
#    c5e98c47-acf7-4ebd-8674-3938bb4f5db7  c7fcb557-2a7c-41d2-92f1-7014b9f639d3  \
# 0                           5666.609288                          10979.201793
# 1                           5662.709733                          10964.916514
# 2                           5610.344292                          11015.108033
# 3                          16226.044899                          51360.209476
# 4                            991.600917                           3571.319639
#
#                    ...                   4e63c197-9a3c-4b2d-9efc-133ceab4bc40  \
# 0                  ...                                           11734.336416
# 1                  ...                                           11719.403012
# 2                  ...                                           11913.122438
# 3                  ...                                           19252.682724
# 4                  ...                                            9526.889044
#
#    dc0f20a0-b439-410e-b661-bdf65e3c17db  c1fc795e-9319-4483-9f13-ba466e839a31  \
# 0                          10890.841967                          10132.541617
# 1                          10859.380777                          10220.210971
# 2                          10940.349424                          10236.628453
# 3                           9641.657043                          15080.770729
# 4                            607.025300                           2144.451515
#
#    d5fcc7c7-e3a7-4dd3-8c0e-512371adf47e  a2e4b2e1-e0c8-4a11-a1f3-cea88b35315c  \
# 0                           5499.395389                           8337.330634
# 1                           5468.023000                           8329.191163
# 2                           5563.524245                           8378.078234
# 3                          18603.827155                          14490.770819
# 4                           3331.932341                           6309.496959
#
#    eed5f427-c2bd-429d-97ac-cc0f4e01de76  12d172c8-5deb-447b-b651-ed10adff51d6  \
# 0                          19997.810283                          13385.740936
# 1                          19880.251089                          13366.544012
# 2                          19987.187464                          13332.263790
# 3                          18488.803478                          45632.459805
# 4                           6906.531801                           1243.686440
#
#    d7ecdf2e-4b2a-4beb-8d66-30c1fdb4a9f7  562b836f-8ced-4938-b21f-9d3d7409cc5a  \
# 0                          14877.067582                          12861.693211
# 1                          14924.389366                          12818.777248
# 2                          14968.894377                          12840.393009
# 3                          13215.922729                          19333.483539
# 4                           3760.016210                           7670.912823
#
#    57e7f0ba-8789-4c64-b000-df5a0db64f9e
# 0                           5711.236196
# 1                           5666.235889
# 2                           5764.475997
# 3                          22303.673483
# 4                            867.681983
#
# [5 rows x 4069 columns]

# %%
# Check dimensions 
miRNA_df.shape
# Out:
# (1881, 4069)

# %%
# Check to see if there are any missing values
miRNA_df.isna().sum().unique()
# Out:
# array([0])

# %%
# Set the miRNA_ID column as the index
miRNA_df.set_index('miRNA_ID', inplace=True)

# %%
# View the dataframe
miRNA_df.head(3)
# Out:
#               dc8d96ef-81eb-41c8-a486-02d107c1a137  \
# miRNA_ID
# hsa-let-7a-1                           3530.574305
# hsa-let-7a-2                           3545.647914
# hsa-let-7a-3                           3516.338118
#
#               93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b  \
# miRNA_ID
# hsa-let-7a-1                           5860.628124
# hsa-let-7a-2                           5770.822052
# hsa-let-7a-3                           5873.585219
#
#               6d869125-0f2b-406a-a1aa-4b352b2247d3  \
# miRNA_ID
# hsa-let-7a-1                          12710.168915
# hsa-let-7a-2                          12822.741990
# hsa-let-7a-3                          12923.054631
#
#               41dbd6ab-871d-4ee4-be13-392b4995f6ce  \
# miRNA_ID
# hsa-let-7a-1                           8612.209891
# hsa-let-7a-2                           8453.920962
# hsa-let-7a-3                           8830.260967
#
#               322badf4-b70d-4f90-ac44-d2f30e52f03c  \
# miRNA_ID
# hsa-let-7a-1                          10317.399990
# hsa-let-7a-2                          10054.249488
# hsa-let-7a-3                          10189.749276
#
#               d681c69f-3020-463b-90c0-bd9435e3f216  \
# miRNA_ID
# hsa-let-7a-1                          39795.949557
# hsa-let-7a-2                          39660.130365
# hsa-let-7a-3                          39721.766849
#
#               28665a83-f3fe-4ebc-a421-2ab1b40ec796  \
# miRNA_ID
# hsa-let-7a-1                          16039.138165
# hsa-let-7a-2                          15971.824671
# hsa-let-7a-3                          15966.266676
#
#               c5e98c47-acf7-4ebd-8674-3938bb4f5db7  \
# miRNA_ID
# hsa-let-7a-1                           5666.609288
# hsa-let-7a-2                           5662.709733
# hsa-let-7a-3                           5610.344292
#
#               c7fcb557-2a7c-41d2-92f1-7014b9f639d3  \
# miRNA_ID
# hsa-let-7a-1                          10979.201793
# hsa-let-7a-2                          10964.916514
# hsa-let-7a-3                          11015.108033
#
#               66b21435-28b2-4721-b0c5-a51a03990240  \
# miRNA_ID
# hsa-let-7a-1                          20656.884281
# hsa-let-7a-2                          20478.207813
# hsa-let-7a-3                          20949.000372
#
#                               ...                   \
# miRNA_ID                      ...
# hsa-let-7a-1                  ...
# hsa-let-7a-2                  ...
# hsa-let-7a-3                  ...
#
#               4e63c197-9a3c-4b2d-9efc-133ceab4bc40  \
# miRNA_ID
# hsa-let-7a-1                          11734.336416
# hsa-let-7a-2                          11719.403012
# hsa-let-7a-3                          11913.122438
#
#               dc0f20a0-b439-410e-b661-bdf65e3c17db  \
# miRNA_ID
# hsa-let-7a-1                          10890.841967
# hsa-let-7a-2                          10859.380777
# hsa-let-7a-3                          10940.349424
#
#               c1fc795e-9319-4483-9f13-ba466e839a31  \
# miRNA_ID
# hsa-let-7a-1                          10132.541617
# hsa-let-7a-2                          10220.210971
# hsa-let-7a-3                          10236.628453
#
#               d5fcc7c7-e3a7-4dd3-8c0e-512371adf47e  \
# miRNA_ID
# hsa-let-7a-1                           5499.395389
# hsa-let-7a-2                           5468.023000
# hsa-let-7a-3                           5563.524245
#
#               a2e4b2e1-e0c8-4a11-a1f3-cea88b35315c  \
# miRNA_ID
# hsa-let-7a-1                           8337.330634
# hsa-let-7a-2                           8329.191163
# hsa-let-7a-3                           8378.078234
#
#               eed5f427-c2bd-429d-97ac-cc0f4e01de76  \
# miRNA_ID
# hsa-let-7a-1                          19997.810283
# hsa-let-7a-2                          19880.251089
# hsa-let-7a-3                          19987.187464
#
#               12d172c8-5deb-447b-b651-ed10adff51d6  \
# miRNA_ID
# hsa-let-7a-1                          13385.740936
# hsa-let-7a-2                          13366.544012
# hsa-let-7a-3                          13332.263790
#
#               d7ecdf2e-4b2a-4beb-8d66-30c1fdb4a9f7  \
# miRNA_ID
# hsa-let-7a-1                          14877.067582
# hsa-let-7a-2                          14924.389366
# hsa-let-7a-3                          14968.894377
#
#               562b836f-8ced-4938-b21f-9d3d7409cc5a  \
# miRNA_ID
# hsa-let-7a-1                          12861.693211
# hsa-let-7a-2                          12818.777248
# hsa-let-7a-3                          12840.393009
#
#               57e7f0ba-8789-4c64-b000-df5a0db64f9e
# miRNA_ID
# hsa-let-7a-1                           5711.236196
# hsa-let-7a-2                           5666.235889
# hsa-let-7a-3                           5764.475997
#
# [3 rows x 4068 columns]

# %%
# Transpose the dataframe
miRNA_df_T = miRNA_df.T.rename_axis('file_ID', axis=1)
miRNA_df_T.columns.name = ''
miRNA_df_T.head(3)
# Out:
#                                       hsa-let-7a-1  hsa-let-7a-2  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3530.574305   3545.647914
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5860.628124   5770.822052
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12710.168915  12822.741990
#
#                                       hsa-let-7a-3    hsa-let-7b   hsa-let-7c  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3516.338118  13112.365384  1015.793793
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5873.585219  32816.747358  2379.637523
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12923.054631   8665.340311   504.349668
#
#                                        hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137   380.189927   608.806338   1039.241630
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   226.078969   395.861593    940.953178
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  1599.429333  4876.308941  12166.251484
#
#                                       hsa-let-7f-2   hsa-let-7g      ...       \
# dc8d96ef-81eb-41c8-a486-02d107c1a137    981.459460   285.561157      ...
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b    928.442879   180.505738      ...
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12349.600700  2128.299868      ...
#
#                                       hsa-mir-941-5  hsa-mir-942  hsa-mir-943  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137            0.0     2.512268     0.000000
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b            0.0     1.787186     0.000000
# 6d869125-0f2b-406a-a1aa-4b352b2247d3            0.0     3.343755     1.114585
#
#                                       hsa-mir-944  hsa-mir-95  hsa-mir-9500  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137     1.674845    2.512268           0.0
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b     4.021167    5.361557           0.0
# 6d869125-0f2b-406a-a1aa-4b352b2247d3    14.489604    3.343755           0.0
#
#                                       hsa-mir-96  hsa-mir-98  hsa-mir-99a  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137   66.993820   42.708560   217.729914
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   35.296914   22.786615   702.363910
# 6d869125-0f2b-406a-a1aa-4b352b2247d3   90.838669  136.536650   112.573075
#
#                                        hsa-mir-99b
# dc8d96ef-81eb-41c8-a486-02d107c1a137  27493.426231
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b  20079.922937
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  43691.728108
#
# [3 rows x 1881 columns]

# %% [markdown]
# ## Log Transform the expression data
#
# Log-transformation will allow us to model proportional changes rather than additive changes. This is biologically more relevant.

# %%
# Offset expression values by 1 to ensure that there are no 0's present in dataframe prior to log transformation
miRNA_df_T = miRNA_df_T.apply(lambda x: x + 1, axis=1)

# %%
# Check to see that there are no 0 values
miRNA_df_T[miRNA_df_T != 0].isna().sum().unique()
# Out:
# array([0])

# %%
# Log transform the data
miRNA_df_T_log = miRNA_df_T.apply(np.log10, axis=1)

# %%
# View the dataframe
miRNA_df_T_log.head(3)
# Out:
#                                       hsa-let-7a-1  hsa-let-7a-2  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137      3.547968      3.549818
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768018      3.761313
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.104185      4.108015
#
#                                       hsa-let-7a-3  hsa-let-7b  hsa-let-7c  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137      3.546214    4.117714    3.007233
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768977    4.516109    3.376693
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.111399    3.937836    2.703592
#
#                                       hsa-let-7d  hsa-let-7e  hsa-let-7f-1  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137    2.581141    2.785192      3.017134
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b    2.356177    2.598639      2.974029
# 6d869125-0f2b-406a-a1aa-4b352b2247d3    3.204237    3.688180      4.085192
#
#                                       hsa-let-7f-2  hsa-let-7g     ...       \
# dc8d96ef-81eb-41c8-a486-02d107c1a137      2.992315    2.457217     ...
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      2.968223    2.258890     ...
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.091688    3.328237     ...
#
#                                       hsa-mir-941-5  hsa-mir-942  hsa-mir-943  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137            0.0     0.545588     0.000000
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b            0.0     0.445166     0.000000
# 6d869125-0f2b-406a-a1aa-4b352b2247d3            0.0     0.637865     0.325225
#
#                                       hsa-mir-944  hsa-mir-95  hsa-mir-9500  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137     0.427299    0.545588           0.0
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b     0.700805    0.803563           0.0
# 6d869125-0f2b-406a-a1aa-4b352b2247d3     1.190040    0.637865           0.0
#
#                                       hsa-mir-96  hsa-mir-98  hsa-mir-99a  \
# dc8d96ef-81eb-41c8-a486-02d107c1a137    1.832469    1.640566     2.339908
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b    1.559870    1.376333     2.847180
# 6d869125-0f2b-406a-a1aa-4b352b2247d3    1.963026    2.138418     2.055275
#
#                                       hsa-mir-99b
# dc8d96ef-81eb-41c8-a486-02d107c1a137     4.439245
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b     4.302784
# 6d869125-0f2b-406a-a1aa-4b352b2247d3     4.640409
#
# [3 rows x 1881 columns]

# %% [markdown]
# ## Assign tumor classification

# %%
samples = pd.read_csv('./manifest/gdc_sample_sheet.2019-02-04.tsv', delimiter='\t')
samples.head()
# Out:
#                                 File ID  \
# 0  65f94233-e5fd-468f-aec6-94f2347d2f34
# 1  dd81dd2f-0be1-4507-b931-9cc2b197b9f8
# 2  347a8e69-dab4-4920-a395-8ee80256d0ff
# 3  406fd7d3-b73a-4014-b315-1eeaae01e988
# 4  2a3fd28d-255b-4079-8348-029bd0755803
#
#                                            File Name            Data Category  \
# 0  35a20c09-b72d-49f3-95b7-91ee3002fd8d.mirbase21...  Transcriptome Profiling
# 1  10db26c3-20bd-4204-bbdc-eb1ad49e91c3.mirbase21...  Transcriptome Profiling
# 2  daf3b479-79cc-4f4e-b136-923ef6156e48.mirbase21...  Transcriptome Profiling
# 3  ed031645-7a24-48a1-a0d5-70ea334abf5f.mirbase21...  Transcriptome Profiling
# 4  589dd6e4-a03e-44bf-bc11-451602e4d22e.mirbase21...  Transcriptome Profiling
#
#                          Data Type Project ID       Case ID         Sample ID  \
# 0  miRNA Expression Quantification  TCGA-BRCA  TCGA-W8-A86G  TCGA-W8-A86G-01A
# 1  miRNA Expression Quantification  TCGA-BRCA  TCGA-AR-A2LH  TCGA-AR-A2LH-01A
# 2  miRNA Expression Quantification  TCGA-BRCA  TCGA-E2-A1B5  TCGA-E2-A1B5-01A
# 3  miRNA Expression Quantification  TCGA-BRCA  TCGA-A8-A07L  TCGA-A8-A07L-01A
# 4  miRNA Expression Quantification  TCGA-BRCA  TCGA-B6-A0IK  TCGA-B6-A0IK-01A
#
#      Sample Type
# 0  Primary Tumor
# 1  Primary Tumor
# 2  Primary Tumor
# 3  Primary Tumor
# 4  Primary Tumor

# %%
merge_df = miRNA_df_T_log.reset_index().merge(samples[['File ID', 'Project ID']], \
                                          how='outer', left_on='index', right_on='File ID').set_index('index')
merge_df.drop('File ID', axis=1, inplace=True)
merge_df.index.names = ['']

# %%
merge_df.head(3)
# Out:
#                                       hsa-let-7a-1  hsa-let-7a-2  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137      3.547968      3.549818
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768018      3.761313
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.104185      4.108015
#
#                                       hsa-let-7a-3  hsa-let-7b  hsa-let-7c  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137      3.546214    4.117714    3.007233
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768977    4.516109    3.376693
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.111399    3.937836    2.703592
#
#                                       hsa-let-7d  hsa-let-7e  hsa-let-7f-1  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137    2.581141    2.785192      3.017134
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b    2.356177    2.598639      2.974029
# 6d869125-0f2b-406a-a1aa-4b352b2247d3    3.204237    3.688180      4.085192
#
#                                       hsa-let-7f-2  hsa-let-7g     ...      \
#                                                                    ...
# dc8d96ef-81eb-41c8-a486-02d107c1a137      2.992315    2.457217     ...
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      2.968223    2.258890     ...
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.091688    3.328237     ...
#
#                                       hsa-mir-942  hsa-mir-943  hsa-mir-944  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137     0.545588     0.000000     0.427299
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b     0.445166     0.000000     0.700805
# 6d869125-0f2b-406a-a1aa-4b352b2247d3     0.637865     0.325225     1.190040
#
#                                       hsa-mir-95  hsa-mir-9500  hsa-mir-96  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137    0.545588           0.0    1.832469
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b    0.803563           0.0    1.559870
# 6d869125-0f2b-406a-a1aa-4b352b2247d3    0.637865           0.0    1.963026
#
#                                       hsa-mir-98  hsa-mir-99a  hsa-mir-99b  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137    1.640566     2.339908     4.439245
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b    1.376333     2.847180     4.302784
# 6d869125-0f2b-406a-a1aa-4b352b2247d3    2.138418     2.055275     4.640409
#
#                                       Project ID
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137   TCGA-BRCA
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   TCGA-BRCA
# 6d869125-0f2b-406a-a1aa-4b352b2247d3   TCGA-LUAD
#
# [3 rows x 1882 columns]

# %%
merge_df[['hsa-let-7a-1', 'hsa-let-7a-2', 'hsa-let-7a-3', 'hsa-let-7b', \
          'hsa-let-7c', 'hsa-let-7d', 'hsa-let-7e', 'Project ID']].head()
# Out:
#                                       hsa-let-7a-1  hsa-let-7a-2  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137      3.547968      3.549818
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768018      3.761313
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.104185      4.108015
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce      3.935165      3.927110
# 322badf4-b70d-4f90-ac44-d2f30e52f03c      4.013612      4.002393
#
#                                       hsa-let-7a-3  hsa-let-7b  hsa-let-7c  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137      3.546214    4.117714    3.007233
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768977    4.516109    3.376693
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.111399    3.937836    2.703592
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce      3.946023    4.527177    3.188055
# 322badf4-b70d-4f90-ac44-d2f30e52f03c      4.008206    4.389196    3.509239
#
#                                       hsa-let-7d  hsa-let-7e Project ID
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137    2.581141    2.785192  TCGA-BRCA
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b    2.356177    2.598639  TCGA-BRCA
# 6d869125-0f2b-406a-a1aa-4b352b2247d3    3.204237    3.688180  TCGA-LUAD
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce    2.909463    3.352680  TCGA-BRCA
# 322badf4-b70d-4f90-ac44-d2f30e52f03c    2.801726    3.011989  TCGA-KIRC

# %% [markdown]
# ## Save Dataframe as CSV

# %%
merge_df.to_csv('./data/expression.csv')
