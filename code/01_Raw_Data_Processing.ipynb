# %%
import os
import sys
import pandas as pd
import numpy as np
from IPython.display import clear_output
import time

# %%
directory = '/Users/surajsakaram/GA_DSI/capstone/data/'
os.chdir(directory)

# %% [markdown]
# #### View one file

# %%
file_path = '46dc2547-0ffe-4bfa-ab8a-bfe04c9d1fc9/2c9af122-8b71-4e50-81b2-e95a5eeaeb03.mirbase21.mirnas.quantification.txt'

df = pd.read_csv(file_path, delimiter='\t')
df.head()
# Out:
#        miRNA_ID  read_count  reads_per_million_miRNA_mapped cross-mapped
# 0  hsa-let-7a-1       56851                    12062.449502            N
# 1  hsa-let-7a-2       56132                    11909.894557            Y
# 2  hsa-let-7a-3       56890                    12070.724388            N
# 3    hsa-let-7b       58020                    12310.483898            N
# 4    hsa-let-7c       22880                     4854.599648            Y

# %% [markdown]
# - Extract out reads_per_million_miRNA_mapped column

# %%
def get_list_of_files(directory, ext='.mirnas.quantification.txt'):
    '''
    ** Description **
    Extract out files of your choosing from subdirectories by specifying file ending or extension.
    
    ** Parameters **
    directory: filepath to parent directory 
    ext: file extension or ending to search by
    '''
    file_paths = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if(file.endswith(ext)):
                file_paths.append(os.path.join(root, file))
    
    return file_paths

# %%
txt_files_paths = get_list_of_files('.')
txt_files_paths[:5]
# Out:
# ['./dc8d96ef-81eb-41c8-a486-02d107c1a137/960e161b-c2da-496e-9aaf-f73a6e14ee46.mirbase21.mirnas.quantification.txt',
#  './93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b/87d84d73-132c-44dc-9aa0-155665590242.mirbase21.mirnas.quantification.txt',
#  './6d869125-0f2b-406a-a1aa-4b352b2247d3/fbfa8b28-c379-4d39-8cae-a420180d2b04.mirbase21.mirnas.quantification.txt',
#  './41dbd6ab-871d-4ee4-be13-392b4995f6ce/2fe32bd1-797d-4614-b974-8e462d99ca2a.mirbase21.mirnas.quantification.txt',
#  './322badf4-b70d-4f90-ac44-d2f30e52f03c/a88f38f8-f19c-49cf-a4f7-6da23f82a596.mirbase21.mirnas.quantification.txt']

# %%
len(txt_files_paths)
# Out:
# 4068

# %%
def process_files(list_of_file_paths):
    # create a dataframe with IDs using one of the files
    df = pd.read_csv(list_of_file_paths[0], delimiter='\t')
    df.drop([col for col in df.columns if col != 'miRNA_ID'], axis=1, inplace=True)
    
    n_files = len(list_of_file_paths)
    
    for i, file in enumerate(list_of_file_paths):
        clear_output(wait=True)
        print(f'Processing file {i}/{n_files}')
    
        sample_id = file.split('/')[1]
        tmp_df = pd.read_csv(file, delimiter='\t')
        tmp_df.rename(columns={'reads_per_million_miRNA_mapped': sample_id}, inplace=True)
        df = pd.merge(df, tmp_df[['miRNA_ID', sample_id]], how='outer', on='miRNA_ID')
    
    return df

# %%
# %%time
# miRNA_df = process_files(txt_files_paths)
# Out:
# Processing file 4067/4068
# CPU times: user 16min 24s, sys: 14.9 s, total: 16min 39s
# Wall time: 16min 51s

# %%
miRNA_df.head()
# Out:
# sample_ID     dc8d96ef-81eb-41c8-a486-02d107c1a137  \
# miRNA_ID
# hsa-let-7a-1                           3530.574305
# hsa-let-7a-2                           3545.647914
# hsa-let-7a-3                           3516.338118
# hsa-let-7b                            13112.365384
# hsa-let-7c                             1015.793793
#
# sample_ID     93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b  \
# miRNA_ID
# hsa-let-7a-1                           5860.628124
# hsa-let-7a-2                           5770.822052
# hsa-let-7a-3                           5873.585219
# hsa-let-7b                            32816.747358
# hsa-let-7c                             2379.637523
#
# sample_ID     6d869125-0f2b-406a-a1aa-4b352b2247d3  \
# miRNA_ID
# hsa-let-7a-1                          12710.168915
# hsa-let-7a-2                          12822.741990
# hsa-let-7a-3                          12923.054631
# hsa-let-7b                             8665.340311
# hsa-let-7c                              504.349668
# ...

# %%
miRNA_df.shape
# Out:
# (1881, 4068)

# %%
miRNA_df.isna().sum().unique()
# Out:
# array([0])

# %%
miRNA_df.set_index('miRNA_ID', inplace=True)

# %%
miRNA_df.head()
# Out:
# sample_ID     dc8d96ef-81eb-41c8-a486-02d107c1a137  \
# miRNA_ID
# hsa-let-7a-1                           3530.574305
# hsa-let-7a-2                           3545.647914
# hsa-let-7a-3                           3516.338118
# hsa-let-7b                            13112.365384
# hsa-let-7c                             1015.793793
#
# sample_ID     93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b  \
# miRNA_ID
# hsa-let-7a-1                           5860.628124
# hsa-let-7a-2                           5770.822052
# hsa-let-7a-3                           5873.585219
# hsa-let-7b                            32816.747358
# hsa-let-7c                             2379.637523
#
# sample_ID     6d869125-0f2b-406a-a1aa-4b352b2247d3  \
# miRNA_ID
# hsa-let-7a-1                          12710.168915
# hsa-let-7a-2                          12822.741990
# hsa-let-7a-3                          12923.054631
# hsa-let-7b                             8665.340311
# hsa-let-7c                              504.349668
# ...

# %%
transposed_df = miRNA_df.T

# %%
transposed_df.head()
# Out:
# miRNA_ID                              hsa-let-7a-1  hsa-let-7a-2  \
# sample_ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3530.574305   3545.647914
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5860.628124   5770.822052
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12710.168915  12822.741990
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8612.209891   8453.920962
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10317.399990  10054.249488
#
# miRNA_ID                              hsa-let-7a-3    hsa-let-7b   hsa-let-7c  \
# sample_ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3516.338118  13112.365384  1015.793793
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5873.585219  32816.747358  2379.637523
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12923.054631   8665.340311   504.349668
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8830.260967  33663.855692  1540.894268
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10189.749276  24500.675020  3229.273903
#
# miRNA_ID                               hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# ...

# %%
transposed_df.index.names = ['sample_ID']
transposed_df.head()
# Out:
# miRNA_ID                              hsa-let-7a-1  hsa-let-7a-2  \
# sample_ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3530.574305   3545.647914
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5860.628124   5770.822052
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12710.168915  12822.741990
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8612.209891   8453.920962
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10317.399990  10054.249488
#
# miRNA_ID                              hsa-let-7a-3    hsa-let-7b   hsa-let-7c  \
# sample_ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3516.338118  13112.365384  1015.793793
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5873.585219  32816.747358  2379.637523
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12923.054631   8665.340311   504.349668
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8830.260967  33663.855692  1540.894268
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10189.749276  24500.675020  3229.273903
#
# miRNA_ID                               hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# ...

# %%
transposed_df['file_id'] = transposed_df.index

# %%
transposed_df.head()
# Out:
# miRNA_ID                              hsa-let-7a-1  hsa-let-7a-2  \
# sample_ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3530.574305   3545.647914
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5860.628124   5770.822052
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12710.168915  12822.741990
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8612.209891   8453.920962
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10317.399990  10054.249488
#
# miRNA_ID                              hsa-let-7a-3    hsa-let-7b   hsa-let-7c  \
# sample_ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3516.338118  13112.365384  1015.793793
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5873.585219  32816.747358  2379.637523
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12923.054631   8665.340311   504.349668
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8830.260967  33663.855692  1540.894268
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10189.749276  24500.675020  3229.273903
#
# miRNA_ID                               hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# ...

# %% [markdown]
# ### Assign tumor classification

# %%
os.chdir('./capstone')
! pwd
# Out:
# /Users/surajsakaram/GA_DSI/capstone

# %%
samples = pd.read_csv('gdc_sample_sheet.2019-02-04.tsv', delimiter='\t')
samples.head()
# Out:
#                                 File ID  \
# 0  65f94233-e5fd-468f-aec6-94f2347d2f34
# 1  dd81dd2f-0be1-4507-b931-9cc2b197b9f8
# 2  347a8e69-dab4-4920-a395-8ee80256d0ff
# 3  406fd7d3-b73a-4014-b315-1eeaae01e988
# 4  2a3fd28d-255b-4079-8348-029bd0755803
#
#                                            File Name            Data Category  \
# 0  35a20c09-b72d-49f3-95b7-91ee3002fd8d.mirbase21...  Transcriptome Profiling
# 1  10db26c3-20bd-4204-bbdc-eb1ad49e91c3.mirbase21...  Transcriptome Profiling
# 2  daf3b479-79cc-4f4e-b136-923ef6156e48.mirbase21...  Transcriptome Profiling
# 3  ed031645-7a24-48a1-a0d5-70ea334abf5f.mirbase21...  Transcriptome Profiling
# 4  589dd6e4-a03e-44bf-bc11-451602e4d22e.mirbase21...  Transcriptome Profiling
#
#                          Data Type Project ID       Case ID         Sample ID  \
# 0  miRNA Expression Quantification  TCGA-BRCA  TCGA-W8-A86G  TCGA-W8-A86G-01A
# 1  miRNA Expression Quantification  TCGA-BRCA  TCGA-AR-A2LH  TCGA-AR-A2LH-01A
# ...

# %%
final_df = pd.merge(transposed_df, samples[['File ID', 'Project ID']], \
                    how='inner', left_on='file_id', right_on='File ID', left_index=True)

# %%
final_df.head()
# Out:
#       hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3    hsa-let-7b   hsa-let-7c  \
# 2758   3530.574305   3545.647914   3516.338118  13112.365384  1015.793793
# 1444   5860.628124   5770.822052   5873.585219  32816.747358  2379.637523
# 1681  12710.168915  12822.741990  12923.054631   8665.340311   504.349668
# 88     8612.209891   8453.920962   8830.260967  33663.855692  1540.894268
# 1937  10317.399990  10054.249488  10189.749276  24500.675020  3229.273903
#
#        hsa-let-7d   hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2   hsa-let-7g  \
# 2758   380.189927   608.806338   1039.241630    981.459460   285.561157
# 1444   226.078969   395.861593    940.953178    928.442879   180.505738
# 1681  1599.429333  4876.308941  12166.251484  12349.600700  2128.299868
# 88     810.826963  2251.579255    814.057349    780.138293  1691.107231
# 1937   632.470045  1026.989244   3458.962567   3501.099696   462.682202
#
#          ...      hsa-mir-944  hsa-mir-95  hsa-mir-9500  hsa-mir-96  \
# ...

# %%
final_df.set_index('File ID', inplace=True)
final_df.head()
# Out:
#                                       hsa-let-7a-1  hsa-let-7a-2  \
# File ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3530.574305   3545.647914
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5860.628124   5770.822052
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12710.168915  12822.741990
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8612.209891   8453.920962
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10317.399990  10054.249488
#
#                                       hsa-let-7a-3    hsa-let-7b   hsa-let-7c  \
# File ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3516.338118  13112.365384  1015.793793
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5873.585219  32816.747358  2379.637523
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12923.054631   8665.340311   504.349668
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8830.260967  33663.855692  1540.894268
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10189.749276  24500.675020  3229.273903
#
#                                        hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# ...

# %%
final_df.drop('file_id', axis=1, inplace=True)

# %%
final_df.head()
# Out:
#                                       hsa-let-7a-1  hsa-let-7a-2  \
# File ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3530.574305   3545.647914
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5860.628124   5770.822052
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12710.168915  12822.741990
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8612.209891   8453.920962
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10317.399990  10054.249488
#
#                                       hsa-let-7a-3    hsa-let-7b   hsa-let-7c  \
# File ID
# dc8d96ef-81eb-41c8-a486-02d107c1a137   3516.338118  13112.365384  1015.793793
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b   5873.585219  32816.747358  2379.637523
# 6d869125-0f2b-406a-a1aa-4b352b2247d3  12923.054631   8665.340311   504.349668
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce   8830.260967  33663.855692  1540.894268
# 322badf4-b70d-4f90-ac44-d2f30e52f03c  10189.749276  24500.675020  3229.273903
#
#                                        hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# ...

# %%
final_df.shape
# Out:
# (4068, 1882)

# %%
# !pwd
# Out:
# /Users/surajsakaram/GA_DSI/capstone

# %%
final_df.to_csv('./expression.csv')
