# %% [markdown]
# # Data Exploration and Visualization
#
# ---
#
# This notebook seeks to explore the data.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pickle

# %% [markdown]
# ## Load Dataset

# %%
directory = '/Users/surajsakaram/GA_DSI/capstone/'
os.chdir(directory)

# %%
# Load dataset
df = pd.read_csv('./data/expression.csv')
df.head()
# Out:
#                              Unnamed: 0  hsa-let-7a-1  hsa-let-7a-2  \
# 0  dc8d96ef-81eb-41c8-a486-02d107c1a137      3.547968      3.549818
# 1  93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768018      3.761313
# 2  6d869125-0f2b-406a-a1aa-4b352b2247d3      4.104185      4.108015
# 3  41dbd6ab-871d-4ee4-be13-392b4995f6ce      3.935165      3.927110
# 4  322badf4-b70d-4f90-ac44-d2f30e52f03c      4.013612      4.002393
#
#    hsa-let-7a-3  hsa-let-7b  hsa-let-7c  hsa-let-7d  hsa-let-7e  hsa-let-7f-1  \
# 0      3.546214    4.117714    3.007233    2.581141    2.785192      3.017134
# 1      3.768977    4.516109    3.376693    2.356177    2.598639      2.974029
# 2      4.111399    3.937836    2.703592    3.204237    3.688180      4.085192
# 3      3.946023    4.527177    3.188055    2.909463    3.352680      2.911188
# 4      4.008206    4.389196    3.509239    2.801726    3.011989      3.539071
#
#    hsa-let-7f-2     ...      hsa-mir-942  hsa-mir-943  hsa-mir-944  \
# ...

# %%
df.set_index('Unnamed: 0', inplace=True)
df.index.name = ''
df.head()
# Out:
#                                       hsa-let-7a-1  hsa-let-7a-2  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137      3.547968      3.549818
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768018      3.761313
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.104185      4.108015
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce      3.935165      3.927110
# 322badf4-b70d-4f90-ac44-d2f30e52f03c      4.013612      4.002393
#
#                                       hsa-let-7a-3  hsa-let-7b  hsa-let-7c  \
#
# dc8d96ef-81eb-41c8-a486-02d107c1a137      3.546214    4.117714    3.007233
# 93b8bab9-acd8-4a5a-b4ba-ec52b2ab186b      3.768977    4.516109    3.376693
# 6d869125-0f2b-406a-a1aa-4b352b2247d3      4.111399    3.937836    2.703592
# 41dbd6ab-871d-4ee4-be13-392b4995f6ce      3.946023    4.527177    3.188055
# 322badf4-b70d-4f90-ac44-d2f30e52f03c      4.008206    4.389196    3.509239
#
#                                       hsa-let-7d  hsa-let-7e  hsa-let-7f-1  \
#
# ...

# %%
df.describe()
# Out:
#        hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3   hsa-let-7b   hsa-let-7c  \
# count   4068.000000   4068.000000   4068.000000  4068.000000  4068.000000
# mean       3.961802      3.960756      3.964243     4.209356     3.292460
# std        0.219981      0.220207      0.219177     0.281252     0.429085
# min        2.805966      2.786798      2.831749     2.985899     1.589490
# 25%        3.813151      3.813330      3.816003     4.031410     3.024067
# 50%        3.953945      3.953049      3.956736     4.206581     3.307055
# 75%        4.111283      4.110697      4.113540     4.385485     3.572379
# max        4.783853      4.785089      4.786539     5.418406     4.777544
#
#         hsa-let-7d   hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2   hsa-let-7g  \
# count  4068.000000  4068.000000   4068.000000   4068.000000  4068.000000
# mean      2.704358     3.025742      3.504666      3.510495     2.768856
# std       0.233459     0.254582      0.319838      0.320314     0.235531
# ...

# %%
# Look at how many samples there are for each class
plt.figure(figsize=(8,5))
ax = sns.countplot(df['Project ID'])
plt.show()
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# ## Correlation of variables

# %%
correlation = df.corr()

# %%
# Serialize the correlation matrix
pickle.dump(correlation, open('./data/correlation.pk', 'wb'))

# %%
correlation.head()
# Out:
#               hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3  hsa-let-7b  \
# hsa-let-7a-1      1.000000      0.999811      0.999791    0.576380
# hsa-let-7a-2      0.999811      1.000000      0.999757    0.575842
# hsa-let-7a-3      0.999791      0.999757      1.000000    0.577602
# hsa-let-7b        0.576380      0.575842      0.577602    1.000000
# hsa-let-7c        0.289790      0.290425      0.290432    0.203842
#
#               hsa-let-7c  hsa-let-7d  hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2  \
# hsa-let-7a-1    0.289790    0.050722    0.546071      0.747227      0.745804
# hsa-let-7a-2    0.290425    0.049526    0.546491      0.747374      0.745931
# hsa-let-7a-3    0.290432    0.052672    0.547338      0.745561      0.744119
# hsa-let-7b      0.203842    0.202242    0.099505      0.076274      0.071545
# hsa-let-7c      1.000000   -0.116143    0.185813      0.121803      0.121842
#
#               hsa-let-7g     ...       hsa-mir-941-5  hsa-mir-942  \
# ...

# %%
correlation[correlation > 0.8]
# Out:
#                 hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3  hsa-let-7b  \
# hsa-let-7a-1        1.000000      0.999811      0.999791         NaN
# hsa-let-7a-2        0.999811      1.000000      0.999757         NaN
# hsa-let-7a-3        0.999791      0.999757      1.000000         NaN
# hsa-let-7b               NaN           NaN           NaN         1.0
# hsa-let-7c               NaN           NaN           NaN         NaN
# hsa-let-7d               NaN           NaN           NaN         NaN
# hsa-let-7e               NaN           NaN           NaN         NaN
# hsa-let-7f-1             NaN           NaN           NaN         NaN
# hsa-let-7f-2             NaN           NaN           NaN         NaN
# hsa-let-7g               NaN           NaN           NaN         NaN
# hsa-let-7i               NaN           NaN           NaN         NaN
# hsa-mir-1-1              NaN           NaN           NaN         NaN
# hsa-mir-1-2              NaN           NaN           NaN         NaN
# ...

# %%
sns.heatmap(correlation)
